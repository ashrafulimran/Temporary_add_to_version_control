# %% [markdown]
# <a href="https://colab.research.google.com/github/ashrafulimran/Temporary_add_to_version_control/blob/master/A1_mimran2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COP 5768 - Intro to Data Science
#
# ## Assignment 1: A crash course in Python
#
# This is the starter ("skeleton") Jupyter notebook for the first assignment.
#
# It is based on a selected subset of tutorials from https://www.learnpython.org/
#
# Please see detailed instructions / guidelines on Canvas.
#
# ---
#
#
# Name: Oge Marques
#
# Open and Execute in Google Colaboratory:https://colab.research.google.com/drive/1mJmONwhrZcSM5ADLzk9sI4hbIGRg2pgA?usp=sharing

# %% [markdown]
# ## Example of a section
#
# The cell below shows an example of a section.
#
# Notice how it's been ***edited to reflect what you have learned*** (rather than just copying and pasting the original contents).

# %% [markdown]
# ### Hello, World!
#
# The first thing I learned, not surprisingly, was how to print a "Hello, World!" message on the screen.
#
# The code below is compatible with the syntax for the `print` statement in Python 3.

# %%
# Hello, World!
print("Hello, World!") # print welcome message
# Out:
# Hello, World!

# %% [markdown]
# ![HelloWorld.png](data:image/png;base64,...)

# %% [markdown]
# ## Take it from here
#
# Add all meaningful sections, code snippets, plots, screenshots, etc. for the selected tutorials (se guidelines for details).

# %% [markdown]
# ##Hello, World!
# The following is the first string that I have written in Python!

# %%
print("This line will be printed.")
# Out:
# This line will be printed.

# %% [markdown]
# ####Indentation
# Indentation is used in Python instead of curly braces. Generally four spaces are used in the standard indentation. For example:

# %%
x = 1
if x == 1:
    # indented four spaces
    print("x is 1.")
# Out:
# x is 1.

# %% [markdown]
# ####Excercise
# In the following excercise, I have printed the string "Hello, World!"

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Variables and Types

# %% [markdown]
# As Python is a completely object oriented, there is no need to declare the variables before its usgae. Also their type declaration is not required.
#
# In this part, I have learned a few basic types of variables.

# %% [markdown]
# ###Numbers
# Integer and floating point numbers are supported in Python. Also complex numbers are supported by Python.

# %%
myint = 7
print(myint)
# Out:
# 7

# %% [markdown]
# ###Defining Floating point number
# The following example represents the way to define floating point number.

# %%
myfloat = 7.0
print(myfloat)
myfloat = float(7)
print(myfloat)
# Out:
# 7.0
# 7.0

# %% [markdown]
# ###Strings
# Single and double quotes are used for defining strings.

# %%
mystring = 'hello'
print(mystring)
mystring = "hello"
print(mystring)
# Out:
# hello
# hello

# %% [markdown]
# Another way: Represent Strings, using double quotes. Using double quotes, it is easier to iclude apostrophes. The following example shows an example of this which could have been terminated if single quotes were used.

# %%
mystring = "Don't worry about apostrophes"
print(mystring)
# Out:
# Don't worry about apostrophes

# %% [markdown]
# Carriage returns, backslashes and Unicode characters can be easily included on defining strings.

# %%
one = 1
two = 2
three = one + two
print(three)

hello = "hello"
world = "world"
helloworld = hello + " " + world
print(helloworld)
# Out:
# 3
# hello world

# %% [markdown]
# Multiple variables can be assigned in the following way:

# %%
a, b = 3, 4
print(a,b)
# Out:
# 3 4

# %% [markdown]
# Numbers and strings mixing for operators is not supported:
# The following example displays an error due to this!

# %%
# This will not work!
one = 1
two = 2
hello = "hello"

print(one + two + hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-fa035bb013ee> in <module>()
#       4 hello = "hello"
#       5
# ----> 6 print(one + two + hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ###Excercise
# In this excercise a string, an interger, and a floating point number are created. String is named as **mystring** and contains the word "hello". **myfloat** is as floating point number, contains the number 10.0, and the integer is named as **myint**, and contains the number 20.

# %%
# change this code
mystring = "hello"
myfloat = 10.0
myint = 20

# testing code
if mystring == "hello":
    print("String: %s" % mystring)
if isinstance(myfloat, float) and myfloat == 10.0:
    print("Float: %f" % myfloat)
if isinstance(myint, int) and myint == 20:
    print("Integer: %d" % myint)
# Out:
# String: hello
# Float: 10.000000
# Integer: 20

# %% [markdown]
# ![1_2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ##Lists
# Lists are like as arrays. In the list, unlimited number of variables can be included. Here is an example:

# %%
mylist = []
mylist.append(1)
mylist.append(2)
mylist.append(3)
print(mylist[0]) # prints 1
print(mylist[1]) # prints 2
print(mylist[2]) # prints 3

# prints out 1,2,3
for x in mylist:
    print(x)
# Out:
# 1
# 2
# 3
# 1
# 2
# 3

# %% [markdown]
# An error is generated if it is tried to access an index which does not exist. The following shows such an example:

# %%
mylist = [1,2,3]
print(mylist[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-ac9eeac6db06> in <module>()
#       1 mylist = [1,2,3]
# ----> 2 print(mylist[10])
#
# IndexError: list index out of range

# %% [markdown]
# ###Exercise
# In this exercise, "append" list method is used to add numbers and strings to the correct list. Numbers 1, 2, and 3 to the "numbers" list, and the words 'hello' and 'world' to the strings variable.
#
# Also, the variable second_name with the second name in the names list, using the brackets operator **[]** is filled.

# %%
numbers = []
strings = []
names = ["John", "Eric", "Jessica"]

# write your code here
numbers.append(1)
numbers.append(2)
numbers.append(3)

strings.append("hello")
strings.append("world")

second_name = names[1]

# this code should write out the filled arrays and the second name in the names list (Eric).
print(numbers)
print(strings)
print("The second name on the names list is %s" % second_name)
# Out:
# [1, 2, 3]
# ['hello', 'world']
# The second name on the names list is Eric

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Basic Operators
# In this section, I have learned the usage of basic operators in Python.

# %% [markdown]
# ###Arithmetic Operators
# Here is an example of the addition, subtraction, multiplication, and division operators in Python:

# %%
number = 1 + 2 * 3 / 4.0
print(number)
# Out:
# 2.5

# %% [markdown]
# Another operator available is the modulo (%) operator, which returns the integer remainder of the division. dividend % divisor = remainder. The following example shows:

# %%
remainder = 11 % 3
print(remainder)
# Out:
# 2

# %% [markdown]
# Two muliplication is used for the square of a number and three is for cube.

# %%
squared = 7 ** 2
cubed = 2 ** 3
print(squared)
print(cubed)
# Out:
# 49
# 8

# %% [markdown]
# ###Using Operators with Strings
# Python allows concatenating strings using the addition operator. Here is an example:

# %%
helloworld = "hello" + " " + "world"
print(helloworld)
# Out:
# hello world

# %% [markdown]
# It is also allowed in Python for multiplying strings to form a string with a repeatating sequence:

# %%
lotsofhellos = "hello" * 10
print(lotsofhellos)
# Out:
# hellohellohellohellohellohellohellohellohellohello

# %% [markdown]
# ###Using Operators with Lists
# Following eample shows that lists can be joined with the addition operators:

# %%
even_numbers = [2,4,6,8]
odd_numbers = [1,3,5,7]
all_numbers = odd_numbers + even_numbers
print(all_numbers)
# Out:
# [1, 3, 5, 7, 2, 4, 6, 8]

# %% [markdown]
# Python also supports forming new lists with a repeating sequence applying the multiplication operator.

# %%
print([1,2,3] * 3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# ###Exercise
# In this excercise two lists called **x_lis**t and **y_list** are created, which contain 10 instances of the variables **x** and **y**, respectively. Also, a list called **big_list** is created, which contains the variables **x** and **y**, 10 times each, by concatenating the two lists.

# %%
x = object()
y = object()

# TODO: change this code
x_list = [x] * 10
y_list = [y] * 10
big_list = x_list + y_list

print("x_list contains %d objects" % len(x_list))
print("y_list contains %d objects" % len(y_list))
print("big_list contains %d objects" % len(big_list))

# testing code
if x_list.count(x) == 10 and y_list.count(y) == 10:
    print("Almost there...")
if big_list.count(x) == 10 and big_list.count(y) == 10:
    print("Great!")
# Out:
# x_list contains 10 objects
# y_list contains 10 objects
# big_list contains 20 objects
# Almost there...
# Great!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##String Formatting
# In this part, I have learned to use string formatting. For Python, **"%"** operator formats a set of variable enclosed in a **"tuple"**-a fixed size list, together with a format string, which contains normal text together with **"argument specifiers"**, special symbols like **"%s**" and **"%d"**.
#
# For this part, **"name"** variable is used with a user name in it, and after that printing will be done (greeting to that user)

# %%
 #This prints out "Hello, John!"
name = "John"
print("Hello, %s!" % name)
# Out:
# Hello, John!

# %% [markdown]
# In case of two or more argument specifiers, a tuple (parentheses) is applied:

# %%
# This prints out "John is 23 years old."
name = "John"
age = 23
print("%s is %d years old." % (name, age))
# Out:
# John is 23 years old.

# %% [markdown]
# **%s** operator can be used for formatting the object which is not a string. The string which returns from the **"repr"** method of that object is formatted as the string. For example:

# %%
# This prints out: A list: [1, 2, 3]
mylist = [1,2,3]
print("A list: %s" % mylist)
# Out:
# A list: [1, 2, 3]

# %% [markdown]
# ###Excercise
# This excercise is performed writting a format string, which prints out the data applying the following syntax: **Hello John Doe. Your current balance is $53.44.**

# %%
data = ("John", "Doe", 53.44)
format_string = "Hello %s %s. Your current balance is $%s."

print(format_string % data)
# Out:
# Hello John Doe. Your current balance is $53.44.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Conditions
# Boolean variables are used to evaluate conditions, for whom True and False are returned as values for comparing or evaluating a condition. Here is an example:

# %%
x = 2
print(x == 2) # prints out True
print(x == 3) # prints out False
print(x < 3) # prints out True
# Out:
# True
# False
# True

# %% [markdown]
# ###Boolean operators
# The example shown below helps me to learn the **"and"** and **"or"** boolean operators for building complex boolean expressions.

# %%
name = "John"
age = 23
if name == "John" and age == 23:
    print("Your name is John, and you are also 23 years old.")

if name == "John" or name == "Rick":
    print("Your name is either John or Rick.")
# Out:
# Your name is John, and you are also 23 years old.
# Your name is either John or Rick.

# %% [markdown]
# ###The "in" operator
# From the "in" operator, I have gained the knowledge to check if a specified object exists within an iterable object container, such as a list:

# %%
name = "John"
if name in ["John", "Rick"]:
    print("Your name is either John or Rick.")
# Out:
# Your name is either John or Rick.

# %% [markdown]
# From the previous lessons, I have learned to use Python indentation for defining code blocks, instead of brackets. Also, it is found that 4 spaces is a standard indentation. In addition to those, I have found that code blocks do not need any termination.
#
# Here is an example for using Python's **"if"** statement using code blocks:

# %%
statement = False
another_statement = True
if statement is True:
    # do something
    pass
elif another_statement is True: # else if
    # do something else
    pass
else:
    # do another thing
    pass

# %% [markdown]
# Another example of **"if"** statement. The following example is evaluated as true if one of the following is correct: 1. The "True" boolean variable is given, or calculated using an expression, such as an arithmetic comparison. 2. An object which is not considered "empty" is passed.
#
# Some examples of objects which are considered as empty: 1. An empty string: **""** 2. An empty list: **[]** 3. The number zero: **0** 4. The false boolean variable: **False**

# %%
x = 2
if x == 2:
    print("x equals two!")
else:
    print("x does not equal to two.")
# Out:
# x equals two!

# %% [markdown]
# ###The 'is' operator
# In this part of tutorial, I have learned tha unlike the double equals operator **"=="**, the "is" operator does not match the values of the variables, but the instances themselves.

# %%
x = [1,2,3]
y = [1,2,3]
print(x == y) # Prints out True
print(x is y) # Prints out False
# Out:
# True
# False

# %% [markdown]
# ###The "not" operator
# In Python if "not" before a boolean is used, that inverts the expression:

# %%
print(not False) # Prints out True
print((not False) == (False)) # Prints out False
# Out:
# True
# False

# %% [markdown]
# ###Excercise
# The following excerscise is conducted changing the variables in the first section, so that each **if** statement resolves as True.

# %%
# change this code
number = 16
second_number = 0
first_array = [1,2,3]
second_array = [1,2]

if number > 15:
    print("1")

if first_array:
    print("2")

if len(second_array) == 2:
    print("3")

if len(first_array) + len(second_array) == 5:
    print("4")

if first_array and first_array[0] == 1:
    print("5")

if not second_number:
    print("6")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Loops
# In this part of the tutorial, loops operations are learned. There are two types of loops in Python, for and while.

# %% [markdown]
# ####The "for" loop
# The following example is for **"for"** loops, which iterate over a given sequence.

# %%
primes = [2, 3, 5, 7]
for prime in primes:
    print(prime)
# Out:
# 2
# 3
# 5
# 7

# %% [markdown]
# **"range"** and **"xrange"** functions allow "for" loops to iterate over a sequence. In the following example, **"range"** function is used. The difference between the **"range"** and **"xrange"** is that range function returns a new lists with numbers that of specified range, whereas **"xrange"** returns an iterator.

# %%
# Prints out the numbers 0,1,2,3,4
for x in range(5):
    print(x)

# Prints out 3,4,5
for x in range(3, 6):
    print(x)

# Prints out 3,5,7
for x in range(3, 8, 2):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 3
# 4
# 5
# 3
# 5
# 7

# %% [markdown]
# ####"while" loops
# In case of "while" loops, it continues as long as a certain boolean condition is met.
# Here is an example:

# %%
# Prints out 0,1,2,3,4

count = 0
while count < 5:
    print(count)
    count += 1  # This is the same as count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ####"break" and "continue" statements
# **"break"** and **"continue"** statements are used in Python for different purpose. **"break"** is used when it is necessary to exit a **"for"** loop, while **"continue"** statement is used to skip the current block, and return to the **"for"** or **"while"** statement. A few examples:

# %%
# Prints out 0,1,2,3,4

count = 0
while True:
    print(count)
    count += 1
    if count >= 5:
        break

# Prints out only odd numbers - 1,3,5,7,9
for x in range(10):
    # Check if x is even
    if x % 2 == 0:
        continue
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ####can we use "else" clause for loops?
# We can also use "else" for loops. This part of the loops execute, when the "for" or "while" statement fails. But if "break" statement is executed inside "for" loop, then the "else" part is skipped. In case of a "continue" statement, "else" part works on the other hand.

# %%
# Prints out 0,1,2,3,4 and then it prints "count value reached 5"

count=0
while(count<5):
    print(count)
    count +=1
else:
    print("count value reached %d" %(count))

# Prints out 1,2,3,4
for i in range(1, 10):
    if(i%5==0):
        break
    print(i)
else:
    print("this is not printed because for loop is terminated because of break but not due to fail in condition")
# Out:
# 0
# 1
# 2
# 3
# 4
# count value reached 5
# 1
# 2
# 3
# 4

# %% [markdown]
# ####Exercise
# In this excercise, loops are applied. All even numbers are printed out from the number list in the same order as they are received. Only numbers that come after 237 in the sequence are not printed.

# %%
numbers = [
    951, 402, 984, 651, 360, 69, 408, 319, 601, 485, 980, 507, 725, 547, 544,
    615, 83, 165, 141, 501, 263, 617, 865, 575, 219, 390, 984, 592, 236, 105, 942, 941,
    386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345,
    399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949, 687, 217,
    815, 67, 104, 58, 512, 24, 892, 894, 767, 553, 81, 379, 843, 831, 445, 742, 717,
    958, 609, 842, 451, 688, 753, 854, 685, 93, 857, 440, 380, 126, 721, 328, 753, 470,
    743, 527
]

# your code goes here
for number in numbers:
    if number == 237:
        break

    if number % 2 == 1:
        continue

    print(number)
# Out:
# 402
# 984
# 360
# 408
# 980
# 544
# 390
# 984
# 592
# 236
# 942
# 386
# 462
# 418
# 344
# 236
# 566
# 978
# 328
# 162
# 758
# 918

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Functions

# %% [markdown]
# ####What are Functions?
# To divide the code into useful blocks, functions are an efficient way. This allows to make the code more readable, and reuse it and save time. In addition to these, functions are a key way to define several interfaces for sharing the code.
#
# ####How do I need to write functions in Python?
# As from the previous tutorial, it is learned that Python makes use of blocks.
#
# The format of the **"block"** is used as follows:
# The block head is of the following format: block_keyword block_name(argument1,argument2, ...)
# Block keywords are "if", "for", and "while".

# %%
block_head:
    1st block line
    2nd block line
    ...

# %% [markdown]
# **"def"** block keyword in Python is used for defining the functions in Python, followed with the function's name as the **block's name**.
# For example:

# %%
def my_function():
    print("Hello From My Function!")

# %% [markdown]
# Receiving arguments is also allowed by the functions(variables passed from the caller to the function). For example:

# %%
def my_function_with_args(username, greeting):
    print("Hello, %s , From My Function!, I wish you %s"%(username, greeting)

# %% [markdown]
# Applying the keyword 'return', functions may return a value to the caller.
# For example:

# %%
def sum_two_numbers(a, b):
    return a + b

# %% [markdown]
# ####How do I need to call functions in Python?
# The function's name followed by (), placing any required areguments within the brackets.
# For example, the functions written in the previous example is called here as follows:

# %%
# Define our 3 functions
def my_function():
    print("Hello From My Function!")

def my_function_with_args(username, greeting):
    print("Hello, %s , From My Function!, I wish you %s"%(username, greeting))

def sum_two_numbers(a, b):
    return a + b

# print(a simple greeting)
my_function()

#prints - "Hello, John Doe, From My Function!, I wish you a great year!"
my_function_with_args("John Doe", "a great year!")

# after this line x will hold the value 3!
x = sum_two_numbers(1,2)
# Out:
# Hello From My Function!
# Hello, John Doe , From My Function!, I wish you a great year!

# %% [markdown]
# ####Exercise
# In this exercise an existing function is used, and also adding something new to create a fully functional program.
#
# 1. A function named **list_benefits()** is added, which returns the following list of strings: **"More organized code", "More readable code", "Easier code reuse", "Allowing programmers to share and connect code together"**.
#
# 2. Another function named **build_sentence(info)** is added, which receives a single argument containing a string and returns a sentence starting with the given string and ending with the string **"is a benefit of functions!"**

# %%
# Modify this function to return a list of strings as defined above
def list_benefits():
    return "More organized code", "More readable code", "Easier code reuse", "Allowing programmers to share and connect code together"

# Modify this function to concatenate to each benefit - " is a benefit of functions!"
def build_sentence(benefit):
    return "%s is a benefit of functions!" % benefit


def name_the_benefits_of_functions():
    list_of_benefits = list_benefits()
    for benefit in list_of_benefits:
        print(build_sentence(benefit))

name_the_benefits_of_functions()
# Out:
# More organized code is a benefit of functions!
# More readable code is a benefit of functions!
# Easier code reuse is a benefit of functions!
# Allowing programmers to share and connect code together is a benefit of functions!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Classes and Objects
# Objects are an encapsulation of variables and functions into a single entity. Objects get their variables and functions from classes. Classes are essentially a template to create your objects.

# %% [markdown]
# The format of the class is like as follows:

# %%
class MyClass:
    variable = "blah"

    def function(self):
        print("This is a message inside the class.")

# %% [markdown]
# To assign the above class to an object, the following is maintained:
# **"myobjectx"** variable holds an object of the class **"MyClass"**, which contains the variable and the function defined within the class called **"MyClass"**.

# %%
class MyClass:
    variable = "blah"

    def function(self):
        print("This is a message inside the class.")

myobjectx = MyClass()

# %% [markdown]
# ####Accessing Object Variables
# For accessing the variable inside of the newly created object "myobjectx" is used:

# %%
class MyClass:
    variable = "blah"

    def function(self):
        print("This is a message inside the class.")

myobjectx = MyClass()

myobjectx.variable
# Out:
# 'blah'

# %% [markdown]
# Another way: The below process would also give the output "blah":

# %%
class MyClass:
    variable = "blah"

    def function(self):
        print("This is a message inside the class.")

myobjectx = MyClass()

print(myobjectx.variable)
# Out:
# blah

# %% [markdown]
# Different type of objetcs that are of the same class(have the same variables and functions defined) can be created. Nonetheless, each object has independent copies of the variables defined in the class.

# %%
class MyClass:
    variable = "blah"

    def function(self):
        print("This is a message inside the class.")

myobjectx = MyClass()
myobjecty = MyClass()

myobjecty.variable = "yackity"

# Then print out both values
print(myobjectx.variable)
print(myobjecty.variable)
# Out:
# blah
# yackity

# %% [markdown]
# ####Accessing Object Functions
# To access a function inside of an object similar notation is used like as variables:

# %%
class MyClass:
    variable = "blah"

    def function(self):
        print("This is a message inside the class.")

myobjectx = MyClass()

myobjectx.function()
# Out:
# This is a message inside the class.

# %% [markdown]
# ####Excercise
# A class is defined for vehicles. I learned to create two new vehicles called car1 and car2. Then, car1 is set to be a red convertible worth $60,000.00 with a name Fer, and car2 is set to a blue van named Jump worth 10,000.00 in the same unit of money as the car1.

# %%
# define the Vehicle class
class Vehicle:
    name = ""
    kind = "car"
    color = ""
    value = 100.00
    def description(self):
        desc_str = "%s is a %s %s worth $%.2f." % (self.name, self.color, self.kind, self.value)
        return desc_str

# your code goes here
car1 = Vehicle()
car1.name = "Fer"
car1.color = "red"
car1.kind = "convertible"
car1.value = 60000.00

car2 = Vehicle()
car2.name = "Jump"
car2.color = "blue"
car2.kind = "van"
car2.value = 10000.00

# test code
print(car1.description())
print(car2.description())
# Out:
# Fer is a red convertible worth $60000.00.
# Jump is a blue van worth $10000.00.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Dictionaries
# A dictionary is a data type similar to arrays, but works with keys and values instead of indexes. Each value stored in a dictionary can be accessed using a key, which is any type of object (a string, a number, a list, etc.) instead of using its index to address it.

# %% [markdown]
# For example, a database of phone numbers could be stored using a dictionary like this:

# %%
phonebook = {}
phonebook["John"] = 938477566
phonebook["Jack"] = 938377264
phonebook["Jill"] = 947662781
print(phonebook)

# %% [markdown]
# Alternatively, a dictionary can be initialized with the same values in the following notation:

# %%
phonebook = {
    "John" : 938477566,
    "Jack" : 938377264,
    "Jill" : 947662781
}
print(phonebook)

# %% [markdown]
# ####Iterating over dictionaries
# Dictionaries can be iterated over, just like a list. However, a dictionary, unlike a list, does not keep the order of the values stored in it. To iterate over key value pairs, use the following syntax:

# %%
phonebook = {"John" : 938477566,"Jack" : 938377264,"Jill" : 947662781}
for name, number in phonebook.items():
    print("Phone number of %s is %d" % (name, number))
# Out:
# Phone number of John is 938477566
# Phone number of Jack is 938377264
# Phone number of Jill is 947662781

# %% [markdown]
# ####Removing a value
# To remove a specified index, use either one of the following notations:

# %%
phonebook = {
   "John" : 938477566,
   "Jack" : 938377264,
   "Jill" : 947662781
}
del phonebook["John"]
print(phonebook)
# Out:
# {'Jack': 938377264, 'Jill': 947662781}

# %% [markdown]
# or:

# %%
phonebook = {
   "John" : 938477566,
   "Jack" : 938377264,
   "Jill" : 947662781
}
phonebook.pop("John")
print(phonebook)
# Out:
# {'Jack': 938377264, 'Jill': 947662781}

# %% [markdown]
# ####Exercise
# Add "Jake" to the phonebook with the phone number 938273443, and remove Jill from the phonebook.

# %%
phonebook = {
    "John" : 938477566,
    "Jack" : 938377264,
    "Jill" : 947662781
}

# write your code here
phonebook["Jake"] = 938273443
del phonebook["Jill"]

# testing code
if "Jake" in phonebook:
    print("Jake is listed in the phonebook.")
if "Jill" not in phonebook:
    print("Jill is not listed in the phonebook.")
# Out:
# Jake is listed in the phonebook.
# Jill is not listed in the phonebook.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Modules and Packages
# In programming, a module is a piece of software that has a specific functionality. For example, when building a ping pong game, one module would be responsible for the game logic, and
# another module would be responsible for drawing the game on the screen. Each module is a different file, which can be edited separately.

# %% [markdown]
# ####Writing modules
# Modules in Python are simply Python files with a .py extension. The name of the module will be the name of the file. A Python module can have a set of functions, classes or variables defined and implemented. In the example above, we will have two files, we will have:

# %%
mygame/
mygame/game.py
mygame/draw.py

# %% [markdown]
# The Python script game.py will implement the game. It will use the function draw_game from the file draw.py, or in other words, thedraw module, that implements the logic for drawing the game on the screen.
#
# Modules are imported from other modules using the import command. In this example, the game.py script may look something like this:

# %%
# game.py
# import the draw module
import draw

def play_game():
    ...

def main():
    result = play_game()
    draw.draw_game(result)

# this means that if this script is executed, then 
# main() will be executed
if __name__ == '__main__':
    main()

# %% [markdown]
# The draw module may look something like this:

# %%
# draw.py

def draw_game():
    ...

def clear_screen(screen):
    ...

# %% [markdown]
# In this example, the game module imports the draw module, which enables it to use functions implemented in that module. The main function would use the local function play_game to run the game, and then draw the result of the game using a function implemented in the draw module called draw_game. To use the function draw_game from the draw module, we would need to specify in which module the function is implemented, using the dot operator. To reference the draw_game function from the game module, we would need to import the draw module and only then call draw.draw_game().
#
# When the import draw directive will run, the Python interpreter will look for a file in the directory which the script was executed from, by the name of the module with a .py prefix, so in our case it will try to look for draw.py. If it will find one, it will import it. If not, he will continue to look for built-in modules.
#
# You may have noticed that when importing a module, a .pyc file appears, which is a compiled Python file. Python compiles files into Python bytecode so that it won't have to parse the files each time modules are loaded. If a .pyc file exists, it gets loaded instead of the .py file, but this process is transparent to the user.

# %% [markdown]
# ####Importing module objects to the current namespace
# We may also import the function draw_game directly into the main script's namespace, by using the from command.

# %%
# game.py
# import the draw module
from draw import draw_game

def main():
    result = play_game()
    draw_game(result)

# %% [markdown]
# You may have noticed that in this example, draw_game does not precede with the name of the module it is imported from, because we've specified the module name in the import command.
#
# The advantages of using this notation is that it is easier to use the functions inside the current module because you don't need to specify which module the function comes from. However, any namespace cannot have two objects with the exact same name, so the import command may replace an existing object in the namespace.

# %% [markdown]
# ####Importing all objects from a module
# We may also use the import * command to import all objects from a specific module, like this:

# %%
# game.py
# import the draw module
from draw import *

def main():
    result = play_game()
    draw_game(result)

# %% [markdown]
# This might be a bit risky as changes in the module might affect the module which imports it, but it is shorter and also does not require you to specify which objects you wish to import from the module.

# %% [markdown]
# ####Custom import name
# We may also load modules under any name we want. This is useful when we want to import a module conditionally to use the same name in the rest of the code.
#
# For example, if you have two draw modules with slighty different names - you may do the following:

# %%
# game.py
# import the draw module
if visual_mode:
    # in visual mode, we draw using graphics
    import draw_visual as draw
else:
    # in textual mode, we print out text
    import draw_textual as draw

def main():
    result = play_game()
    # this can either be visual or textual depending on visual_mode
    draw.draw_game(result)

# %% [markdown]
# ####Module initialization
# The first time a module is loaded into a running Python script, it is initialized by executing the code in the module once. If another module in your code imports the same module again, it will not be loaded twice but once only - so local variables inside the module act as a "singleton" - they are initialized only once.
#
# This is useful to know, because this means that you can rely on this behavior for initializing objects. For example:

# %%
# draw.py

def draw_game():
    # when clearing the screen we can use the main screen object initialized in this module
    clear_screen(main_screen)
    ...

def clear_screen(screen):
    ...

class Screen():
    ...

# initialize main_screen as a singleton
main_screen = Screen()

# %% [markdown]
# ####Extending module load path
# There are a couple of ways we could tell the Python interpreter where to look for modules, aside from the default, which is the local directory and the built-in modules. You could either use the environment variable PYTHONPATH to specify additional directories to look for modules in, like this:

# %%
PYTHONPATH=/foo python game.py

# %% [markdown]
# This will execute game.py, and will enable the script to load modules from the foo directory as well as the local directory.
#
# Another method is the sys.path.append function. You may execute it before running an import command:

# %%
sys.path.append("/foo")

# %% [markdown]
# ####Exploring built-in modules
# Check out the full list of built-in modules in the Python standard library here.
#
# Two very important functions come in handy when exploring modules in Python - the dir and help functions.
#
# If we want to import the module urllib, which enables us to create read data from URLs, we simply import the module:

# %%
# import the library
import urllib

# use it
urllib.urlopen(...)

# %% [markdown]
# We can look for which functions are implemented in each module by using the dir function:

# %%
>>> import urllib
>>> dir(urllib)
['ContentTooShortError', 'FancyURLopener', 'MAXFTPCACHE', 'URLopener', '__all__', '__builtins__', 
'__doc__', '__file__', '__name__', '__package__', '__version__', '_ftperrors', '_get_proxies', 
'_get_proxy_settings', '_have_ssl', '_hexdig', '_hextochr', '_hostprog', '_is_unicode', '_localhost', 
'_noheaders', '_nportprog', '_passwdprog', '_portprog', '_queryprog', '_safe_map', '_safe_quoters', 
'_tagprog', '_thishost', '_typeprog', '_urlopener', '_userprog', '_valueprog', 'addbase', 'addclosehook', 
'addinfo', 'addinfourl', 'always_safe', 'basejoin', 'c', 'ftpcache', 'ftperrors', 'ftpwrapper', 'getproxies', 
'getproxies_environment', 'getproxies_macosx_sysconf', 'i', 'localhost', 'main', 'noheaders', 'os', 
'pathname2url', 'proxy_bypass', 'proxy_bypass_environment', 'proxy_bypass_macosx_sysconf', 'quote', 
'quote_plus', 'reporthook', 'socket', 'splitattr', 'splithost', 'splitnport', 'splitpasswd', 'splitport', 
'splitquery', 'splittag', 'splittype', 'splituser', 'splitvalue', 'ssl', 'string', 'sys', 'test', 'test1', 
'thishost', 'time', 'toBytes', 'unquote', 'unquote_plus', 'unwrap', 'url2pathname', 'urlcleanup', 'urlencode', 
'urlopen', 'urlretrieve']
# Out:
# ['ContentTooShortError',
#  'FancyURLopener',
#  'MAXFTPCACHE',
#  'URLopener',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__version__',
#  '_ftperrors',
#  '_get_proxies',
#  '_get_proxy_settings',
#  '_have_ssl',
#  '_hexdig',
#  '_hextochr',
#  '_hostprog',
#  '_is_unicode',
#  '_localhost',
#  '_noheaders',
#  '_nportprog',
#  '_passwdprog',
#  '_portprog',
#  '_queryprog',
#  '_safe_map',
#  '_safe_quoters',
#  '_tagprog',
#  '_thishost',
#  '_typeprog',
#  '_urlopener',
#  '_userprog',
#  '_valueprog',
#  'addbase',
#  'addclosehook',
#  'addinfo',
#  'addinfourl',
#  'always_safe',
#  'basejoin',
#  'c',
#  'ftpcache',
#  'ftperrors',
#  'ftpwrapper',
#  'getproxies',
#  'getproxies_environment',
#  'getproxies_macosx_sysconf',
#  'i',
#  'localhost',
#  'main',
#  'noheaders',
#  'os',
#  'pathname2url',
#  'proxy_bypass',
#  'proxy_bypass_environment',
#  'proxy_bypass_macosx_sysconf',
#  'quote',
#  'quote_plus',
# ...

# %% [markdown]
# When we find the function in the module we want to use, we can read about it more using the help function, inside the Python interpreter:

# %%
help(urllib.urlopen)

# %% [markdown]
# ####Writing packages
# Packages are namespaces which contain multiple packages and modules themselves. They are simply directories, but with a twist.
#
# Each package in Python is a directory which MUST contain a special file called __init__.py. This file can be empty, and it indicates that the directory it contains is a Python package, so it can be imported the same way a module can be imported.
#
# If we create a directory called foo, which marks the package name, we can then create a module inside that package called bar. We also must not forget to add the __init__.py file inside the foo directory.
#
# To use the module bar, we can import it in two ways:

# %%
import foo.bar

# %% [markdown]
# Or:

# %%
from foo import bar

# %% [markdown]
# In the first method, we must use the foo prefix whenever we access the module bar. In the second method, we don't, because we import the module to our module's namespace.
#
# The __init__.py file can also decide which modules the package exports as the API, while keeping other modules internal, by overriding the __all__ variable, like so:

# %%
__init__.py:

__all__ = ["bar"]

# %% [markdown]
# ####Exercise
# In this exercise, you will need to print an alphabetically sorted list of all functions in the re module, which contain the word find.

# %%
import re

# Your code goes here
find_members = []
for member in dir(re):
    if "find" in member:
        find_members.append(member)

print(sorted(find_members))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Numpy Arrays

# %% [markdown]
# ####Getting started
# Numpy arrays are great alternatives to Python Lists. Some of the key advantages of Numpy arrays are that they are fast, easy to work with, and give users the opportunity to perform calculations across entire arrays.
#
# In the following example, you will first create two Python lists. Then, you will import the numpy package and create numpy arrays out of the newly created lists.

# %%
# Create 2 new lists height and weight
height = [1.87,  1.87, 1.82, 1.91, 1.90, 1.85]
weight = [81.65, 97.52, 95.25, 92.98, 86.18, 88.45]

# Import the numpy package as np
import numpy as np

# Create 2 numpy arrays from height and weight
np_height = np.array(height)
np_weight = np.array(weight)

# %% [markdown]
# ####Print out the type of np_height

# %%
print(type(np_height))

# %% [markdown]
# ####Element-wise calculations
# Now we can perform element-wise calculations on height and weight. For example, you could take all 6 of the height and weight observations above, and calculate the BMI for each observation with a single equation. These operations are very fast and computationally efficient. They are particularly helpful when you have 1000s of observations in your data.

# %%
# Calculate bmi
bmi = np_weight / np_height ** 2

# Print the result
print(bmi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bd0820416d20> in <module>()
#       1 # Calculate bmi
# ----> 2 bmi = np_weight / np_height ** 2
#       3
#       4 # Print the result
#       5 print(bmi)
#
# NameError: name 'np_weight' is not defined

# %% [markdown]
# ####Subsetting
# Another great feature of Numpy arrays is the ability to subset. For instance, if you wanted to know which observations in our BMI array are above 23, we could quickly subset it to find out.

# %%
# Calculate bmi
bmi = np_weight / np_height ** 2

# Print the result
print(bmi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-bd0820416d20> in <module>()
#       1 # Calculate bmi
# ----> 2 bmi = np_weight / np_height ** 2
#       3
#       4 # Print the result
#       5 print(bmi)
#
# NameError: name 'np_weight' is not defined

# %% [markdown]
# ####Exercise
# First, convert the list of weights from a list to a Numpy array. Then, convert all of the weights from kilograms to pounds. Use the scalar conversion of 2.2 lbs per kilogram to make your conversion. Lastly, print the resulting array of weights in pounds.

# %%
weight_kg = [81.65, 97.52, 95.25, 92.98, 86.18, 88.45]

import numpy as np

# Create a numpy array np_weight_kg from weight_kg
np_weight_kg = np.array(weight_kg)

# Create np_weight_lbs from np_weight_kg
np_weight_lbs = np_weight_kg * 2.2

# Print out np_weight_lbs
print(np_weight_lbs)
# Out:
# [179.63  214.544 209.55  204.556 189.596 194.59 ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Pandas Basics

# %% [markdown]
# ####Pandas DataFrames
# Pandas is a high-level data manipulation tool developed by Wes McKinney. It is built on the Numpy package and its key data structure is called the DataFrame. DataFrames allow you to store and manipulate tabular data in rows of observations and columns of variables.
#
# There are several ways to create a DataFrame. One way way is to use a dictionary. For example:

# %%
dict = {"country": ["Brazil", "Russia", "India", "China", "South Africa"],
       "capital": ["Brasilia", "Moscow", "New Dehli", "Beijing", "Pretoria"],
       "area": [8.516, 17.10, 3.286, 9.597, 1.221],
       "population": [200.4, 143.5, 1252, 1357, 52.98] }

import pandas as pd
brics = pd.DataFrame(dict)
print(brics)
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Dehli   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# As you can see with the new brics DataFrame, Pandas has assigned a key for each country as the numerical values 0 through 4. If you would like to have different index values, say, the two letter country code, you can do that easily as well.

# %%
# Set the index for brics
brics.index = ["BR", "RU", "IN", "CH", "SA"]

# Print out brics with new index values
print(brics)
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Dehli   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# Another way to create a DataFrame is by importing a csv file using Pandas. Now, the csv cars.csv is stored and can be imported using pd.read_csv:

# %%
# Import pandas as pd
import pandas as pd

# Import the cars.csv data: cars
cars = pd.read_csv('cars.csv')

# Print out cars
print(cars)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-af72f3ad31e4> in <module>()
#       3
#       4 # Import the cars.csv data: cars
# ----> 5 cars = pd.read_csv('cars.csv')
#       6
#       7 # Print out cars
#
# ...

# %% [markdown]
# ####Indexing DataFrames
# There are several ways to index a Pandas DataFrame. One of the easiest ways to do this is by using square bracket notation.
#
# In the example below, you can use square brackets to select one column of the cars DataFrame. You can either use a single bracket or a double bracket. The single bracket with output a Pandas Series, while a double bracket will output a Pandas DataFrame.

# %%
# Import pandas and cars.csv
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Print out country column as Pandas Series
print(cars['cars_per_cap'])

# Print out country column as Pandas DataFrame
print(cars[['cars_per_cap']])

# Print out DataFrame with country and drives_right columns
print(cars[['cars_per_cap', 'country']])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-b5ef16891d3d> in <module>()
#       1 # Import pandas and cars.csv
#       2 import pandas as pd
# ----> 3 cars = pd.read_csv('cars.csv', index_col = 0)
#       4
#       5 # Print out country column as Pandas Series
#
# ...

# %% [markdown]
# Square brackets can also be used to access observations (rows) from a DataFrame. For example:

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Print out first 4 observations
print(cars[0:4])

# Print out fifth and sixth observation
print(cars[4:6])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-de1e12215b9c> in <module>()
#       1 # Import cars data
#       2 import pandas as pd
# ----> 3 cars = pd.read_csv('cars.csv', index_col = 0)
#       4
#       5 # Print out first 4 observations
#
# ...

# %% [markdown]
# You can also use loc and iloc to perform just about any data selection operation. loc is label-based, which means that you have to specify rows and columns based on their row and column labels. iloc is integer index based, so you have to specify rows and columns by their integer index like you did in the previous exercise.

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Print out observation for Japan
print(cars.iloc[2])

# Print out observations for Australia and Egypt
print(cars.loc[['AUS', 'EG']])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-7f48fd5884d2> in <module>()
#       1 # Import cars data
#       2 import pandas as pd
# ----> 3 cars = pd.read_csv('cars.csv', index_col = 0)
#       4
#       5 # Print out observation for Japan
#
# ...

# %% [markdown]
# ### Dictionaries
#
# A dictionary is a data structure that works with *keys* and *values*.
#
# ## **Below is VERBATIM - Edit before submission to avoid plagiarism issues.**
#
# Each value stored in a dictionary can be accessed using a key, which is any type of object (a string, a number, a list, etc.) instead of using its index to address it.

# %%
phonebook = {}
phonebook["John"] = 938477566
phonebook["Jack"] = 938377264
phonebook["Jill"] = 947662781
print(phonebook)
# Out:
# {'John': 938477566, 'Jack': 938377264, 'Jill': 947662781}

# %% [markdown]
# Another way:

# %%
phonebook = {
    "John" : 938477566,
    "Jack" : 938377264,
    "Jill" : 947662781
}
print(phonebook)
# Out:
# {'John': 938477566, 'Jack': 938377264, 'Jill': 947662781}

# %%
a = 4
print(a)
# Out:
# 4

# %%
a = 2*a
print(a)
# Out:
# 8

# %% [markdown]
# ###Concluding Remarks
#
# I also did this...
